# %% [markdown]
# #TEST ESTADÍSTICOS
#
# ##1. Conociendo y Explorando los Datos
#
# ###Importando y conociendo los Datasets

# %%
import pandas as pd
tmdb= pd.read_csv('tmdb_5000_movies.csv', )

# %%
tmdb.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# ###Visualizando una distribución

# %%
import seaborn as sns
sns.distplot(tmdb['vote_average'])#Gráfico de distribución de frecuencias
# Out:
# <ipython-input-4-1e1d2b10375c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tmdb['vote_average'])#Gráfico de distribución de frecuencias
# <Axes: xlabel='vote_average', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(tmdb.vote_average,
             kde=False,#Desactivamos estos parámetros
             norm_hist=False)
# Out:
# <ipython-input-5-1eb781ba20a1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tmdb.vote_average,
# <Axes: xlabel='vote_average'>

# %%
ax= sns.distplot(tmdb.vote_average,
             kde=False,#Desactivamos estos parámetros
             norm_hist=False)
ax.set(xlabel='Nota Promedio', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# <ipython-input-6-303c6c499e7c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.vote_average,
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %%
sns.boxplot(tmdb.vote_average)
# Out:
# <Axes: ylabel='vote_average'>

# %% [markdown]
# ###Limpiando mi conjunto de datos

# %%
tmdb.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %% [markdown]
# La tabla nos muestra 63 filas con promedio 0 pero tambien tienen 0 votos, como si existiera un error de base. por lo cual, se debe excluir esa distribución ya que nos afectan o ensucian nuestra base de datos

# %%
tmdb.query('vote_count < 10')#Filtramos la variable ''vote_count' para aquellos que tuvieron menos de 10 votos
# Out:
#         budget                                             genres  \
# 463          0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 492    8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
# 1023         0                      [{"id": 18, "name": "Drama"}]
# 1039  46000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 1453         0  [{"id": 14, "name": "Fantasy"}, {"id": 10751, ...
# ...        ...                                                ...
# 4795         0                      [{"id": 18, "name": "Drama"}]
# 4797         0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799      9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801         0                                                 []
#
#                                                homepage      id  \
# 463                                                 NaN  161795
# ...

# %%
#usamos aquellas peliculas que tienen 10 o más votos
tmdb_10_o_mas_votos= tmdb.query('vote_count >= 10')

# %%
ax= sns.displot(tmdb_10_o_mas_votos.vote_average)
ax.set(xlabel='Nota Promedio', ylabel = 'Densidad')
ax.fig.suptitle('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# Text(0.5, 0.98, 'Gráfico de Distribución de Notas Promedio TMDB')

# %%
ax= sns.distplot(tmdb_10_o_mas_votos.vote_average,
            kde= False,#Desactivamos estos parámetros
             norm_hist= False)
ax.set(xlabel='Nota Promedio', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
#Frecuecnia: Cantidad de veces que se repite cada nota
# Out:
# <ipython-input-12-392ea49d9408>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb_10_o_mas_votos.vote_average,
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %%
ax= sns.boxplot(x= tmdb_10_o_mas_votos.vote_average) #Se cambia la orientación del gráfico con 'x= o y='
ax.set(xlabel='Nota Promedio')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %% [markdown]
# El Gráfico e BoxPlot muestra que ya no se cuenta con valores 0, los datos estan menos densos al lado izquierdo de la media. Además, se observa la presencia de outlayers.

# %% [markdown]
# ###Visualizando y Limpiando Movielens (Lentes de Películas)

# %%
notas= pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_promedio_por_pelicula= notas.groupby('movieId').mean()['rating']
nota_promedio_por_pelicula.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
sns.distplot(nota_promedio_por_pelicula.values)#Pasamos la serie de tiempo a DataFramse con la función .values
# Out:
# <ipython-input-16-46b26378d452>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(nota_promedio_por_pelicula.values)#Pasamos la serie de tiempo a DataFramse con la función .values
# <Axes: ylabel='Density'>

# %%
#Limpieza de datos
cantidad_votos_por_pelicula= notas.groupby('movieId').count()
cantidad_votos_por_pelicula.head()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 4             7       7          7
# 5            49      49         49

# %%
#Filtramos los regiustros que tengan más de 10 votos
peliculas_10_o_mas_votos= cantidad_votos_por_pelicula.query('rating > 10').index

# %%
#Muestra una serie con cada uno de los Id que tienen 10 o más votos
peliculas_10_o_mas_votos
# Out:
# Index([     1,      2,      3,      5,      6,      7,      9,     10,     11,
#            12,
#        ...
#        159093, 164179, 166528, 168250, 168252, 174055, 176371, 177765, 179819,
#        187593],
#       dtype='int64', name='movieId', length=2121)

# %%
#Excluimos los registros que tienen menos de 10 votos
nota_promedio_por_pelicula_10_o_mas_votos=   nota_promedio_por_pelicula.loc[peliculas_10_o_mas_votos.values]
nota_promedio_por_pelicula_10_o_mas_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
#Gráficamos nuevamente
ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values)
ax.set(xlabel='Nota Promedio', ylabel = 'Densidad')
ax.set_title('Gráfico de Distribución de Notas Promedio MoviLens')
# Out:
# <ipython-input-21-0e9f8a43189b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values)
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio MoviLens')

# %%
#Gráficamos nuevamente sin los parámetros
ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values,
                 kde= False,#Desactivamos estos parámetros
             norm_hist= False)
ax.set(xlabel='Nota Promedio', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de Notas Promedio MoviLens')
# Out:
# <ipython-input-22-c33527f54b63>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values,
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio MoviLens')

# %%
#Gráficamos nuevamente el BoxPlot
ax= sns.boxplot(x= nota_promedio_por_pelicula_10_o_mas_votos.values) #Se cambia la orientación del gráfico con 'x= o y='
ax.set(xlabel='Nota Promedio')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %% [markdown]
# Aprendimos:
#
# - Importar archivos .csv;
# - Mostrar los primeros 5 elementos;
# - Mostrar informaciones con la función describe();
# - Generar gráficos de histograma;
# - Generar gráficos de boxplot;
# - Realizar una query();

# %% [markdown]
# ## 2.Explorando la Distribución de las Muestras
#
# ### 2.1 Visualizando la distribucion acumulada

# %%
ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values,
                 hist_kws= {'cumulative': True},
                 kde_kws= {'cumulative': True})#PAsamos estos parámetros para ver el acumulado
ax.set(xlabel='Nota Promedio', ylabel = '% Acumulado')
ax.set_title('Gráfico de Distribución de Notas Promedio MoviLens')
# Out:
# <ipython-input-24-890e762e636b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values,
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio MoviLens')

# %% [markdown]
# La nota promedio de la primer película de Movilends fue de 3.920930, si la buscamos en el gráfico por encima del 80%. Por tanto, se puede deducir que esa película esta dentro del 20% de las mejores films. De esta manera es posible haer un análisis para cualquier película.

# %%
#Hacemos lo mismo para el gráfico TMDB
ax= sns.distplot(tmdb_10_o_mas_votos.vote_average,
                 hist_kws= {'cumulative': True},
                 kde_kws= {'cumulative': True})
ax.set(xlabel='Nota Promedio', ylabel = '% Acumulado')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# <ipython-input-25-b5fc9a0cc351>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb_10_o_mas_votos.vote_average,
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %% [markdown]
# Como 7 esta por encia del 80%, se puede afirmasr que: el 20% de las mejores películas tienen una nota igula o mayor a 7

# %% [markdown]
# ### 2.3 Analizando otras variables

# %%
#Graficamos la distribución de la variable Cantidad de Votos
ax= sns.distplot(tmdb_10_o_mas_votos.vote_count)
ax.set(xlabel='Cantidad de Votos', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de la cantidad de votos TMDB')
# Out:
# <ipython-input-26-778ade9190c6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb_10_o_mas_votos.vote_count)
# Text(0.5, 1.0, 'Gráfico de Distribución de la cantidad de votos TMDB')

# %%
#Analizamos la variable Presumpuesto (budget)
tmdb.budget
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %% [markdown]
# Se puede obesrvar, existen peliculas con presupuesto = 0

# %%
#Observamos cuantos registros hay con presupuesto = 0
tmdb.query('budget == 0')
# Out:
#       budget                                             genres  \
# 265        0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 321        0                     [{"id": 35, "name": "Comedy"}]
# 359        0  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 406        0  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 409        0  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# ...      ...                                                ...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 265                                                 NaN   10588
# 321                                                 NaN   77953
# ...

# %%
#Graficamos cuantos los registros  con presupuesto mayor que 0
ax= sns.distplot(tmdb.query('budget > 0').budget)
ax.set(xlabel='Presupuesto de las Películas', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución del Presupuesto de las Películas TMDB')
# Out:
# <ipython-input-29-429e5d349b39>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.query('budget > 0').budget)
# Text(0.5, 1.0, 'Gráfico de Distribución del Presupuesto de las Películas TMDB')

# %% [markdown]
# Al analizar el gráfico, observamos que el eje X está representado en una escala basada en el presupuesto, donde los valores están expresados en unidades (1e8). Es decir, 1 y 8 ceros. (100.000.000).
# El gráfico muestra que la mayor cantidad de películas no gastaron 100.000.000 millonres de dolares para ser realizadas. son pocas las películas que gastaron un monto superior.

# %%
#Analizamos la variable 'Popularidad'
tmdb.query('popularity == 0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %% [markdown]
# Solo existe un registro en nuestro DataSet donde la popularidad de  igual a 0

# %%
#Graficamos la distribución de la variable popularidad
ax= sns.distplot(tmdb.popularity)
ax.set(xlabel='Popularidad de las Películas', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de la Popularidad de las Películas TMDB')
# Out:
# <ipython-input-31-684a592f4629>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.popularity)
# Text(0.5, 1.0, 'Gráfico de Distribución de la Popularidad de las Películas TMDB')

# %%
#Analizamos y gráficamos la variable runtime (Duración)
ax= sns.distplot(tmdb.runtime)
ax.set(xlabel='Duración de las Películas', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de la Duración de las Películas TMDB')
# Out:
# <ipython-input-32-3f4c228648fb>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.runtime)
# Text(0.5, 1.0, 'Gráfico de Distribución de la Duración de las Películas TMDB')

# %% [markdown]
# El Gráfico muestra que la mayor cantidad de peliculas tienen poca popularidad

# %%
#Existen dos registros que vinieron con valores nulos en la variable runtime
tmdb.runtime.isnull().sum()
# Out:
# 2

# %%
#Analizamos y gráficamos la variable runtime (Duración) sin datos nulos
ax= sns.distplot(tmdb.query('runtime > 0').runtime.dropna())# La función .dropna() elimina los registros nulos
ax.set(xlabel='Duración de las Películas', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de la Duración de las Películas TMDB')
# Out:
# <ipython-input-34-b30385685d18>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.query('runtime > 0').runtime.dropna())# La función .dropna() elimina los registros nulos
# Text(0.5, 1.0, 'Gráfico de Distribución de la Duración de las Películas TMDB')

# %% [markdown]
# El gráfico muestra que la mayoria de peliculas tienen una Duración entre 80 a 120 minutos.

# %%
#Graficamos los acumulados de la variable 'runtime'
ax= sns.distplot(tmdb.query('runtime > 0').runtime.dropna(),
                 hist_kws= {'cumulative': True},
                 kde_kws= {'cumulative': True})
ax.set(xlabel='Duración', ylabel = '% Acumulado')
ax.set_title('Gráfico de Distribución de la Duración de las Películas TMDB')
# Out:
# <ipython-input-35-591bbf854bfc>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.query('runtime > 0').runtime.dropna(),
# Text(0.5, 1.0, 'Gráfico de Distribución de la Duración de las Películas TMDB')

# %% [markdown]
# El gráfico muestra que aproximaamente el 40% de las películas tienen menos de 100 minutos

# %%
#Donde estan ubicados el 40% de todos los registros
tmdb.query('runtime > 0').runtime.dropna().quantile(0.4)
# Out:
# 100.0

# %%
#Donde estan ubicados el 80% de todos los registros
tmdb.query('runtime > 0').runtime.dropna().quantile(0.8)
# Out:
# 121.0

# %% [markdown]
# Se confirma que el 80% de las películas tienen 121 o menos minutos de duración

# %% [markdown]
# Aprendimos:
#
# - Remover valores NaN;
# - Utilizar query() para realizar filtros en los datos;
# - Visualizar gráficos de manera acumulada
# - Filtrar una única columna;
# - Separación de datos con quantile();

# %% [markdown]
# ## 3. Test de una muestra
#
# ### 3.1 Efecto del tamaño de una muestra

# %%
#Calculamos el Promedio del Promedop de las Películas
nota_promedio_por_pelicula_10_o_mas_votos.mean()
# Out:
# 3.443810571746584

# %%
#Tamaño de la variable nota_promedio_por_pelicula_10_o_mas_votos
len(nota_promedio_por_pelicula_10_o_mas_votos)
#Existen 2121 películas
# Out:
# 2121

# %%
#El Promedio del promedio de las 6 primeras películas es:
nota_promedio_por_pelicula_10_o_mas_votos[0:5].mean()
# Out:
# 3.5259741603585653

# %% [markdown]
# Las 6 primeras películas tienen un promedio mayor que el promedio de todas las películas.

# %%
#Analizamos como se comporta el acumualado de los promedios
import matplotlib.pyplot as plt

promedios = list()
for i in range(1, len(nota_promedio_por_pelicula_10_o_mas_votos)):
  promedios.append(nota_promedio_por_pelicula_10_o_mas_votos[0:i].mean())

promedios

plt.plot(promedios)

# %% [markdown]
# Los primeros registros muestran una oscilación muy grande, en la medida en que crecen los datos la serie se comienza a estabilizar, cuanto más gande es la muestra, los datos son más consistentes.

# %%
#Validamos si el comportamiento es el mismo otorgando un orden aleatorio
import numpy as np

np.random.seed(75243)#Colocamos una semilla, un parametro fijo de 75243
temp =nota_promedio_por_pelicula_10_o_mas_votos.sample(frac=1)

promedios = list()
for i in range(1, len(temp)):
  promedios.append(temp[0:i].mean())

promedios

plt.plot(promedios)

# %% [markdown]
# Al ordenar el conjunto de datos utilizando el código anterior, se observa que los valores se estabilizan a partir de 500, en lugar de a partir de 1000 como en el gráfico previo. Esto sugiere que, además del número de muestras, el orden de los datos también puede influir en los resultados. Si se extraen muestras de datos no aleatorios, por ejemplo, ordenados de mayor a menor, la probabilidad de tomar decisiones erróneas aumenta significativamente. Por ello, es fundamental utilizar datos aleatorios para garantizar un análisis adecuado de las tendencias y la consistencia de la información.

# %% [markdown]
# ### 3.2 Intervalo de confianza

# %%
nota_promedio_por_pelicula_10_o_mas_votos.mean()
# Out:
# 3.443810571746584

# %%
#Analizando Test Estadísticos Z Test
from statsmodels.stats.weightstats import zconfint # PAra calcular el intervalo de confianza con el Test Z usamos 'zconfint'

zconfint(nota_promedio_por_pelicula_10_o_mas_votos)
# Out:
# (3.422668132218516, 3.464953011274652)

# %% [markdown]
# El resultado muestra que hay un 5% de probabilidad de que, al seleccionar un dato aleatorio del universo, no se encuentre dentro del intervalo de confianza (3.422668132218516, 3.464953011274652). Por lo tanto, existe un 95% de confianza en que, al elegir un dato aleatorio, este estará dentro de dicho intervalo.
# Se recomienda usar Z Tets con volumenes grandes de datos y T Test con volumenes más cortos de datos

# %%
#Analizando Test Estadísticos  T Test
from statsmodels.stats.weightstats import DescrStatsW # PAra calcular el intervalo de confianza con el Test T usamos 'DescrStatsW'

descr_notas_10_votos= DescrStatsW(nota_promedio_por_pelicula_10_o_mas_votos)
descr_notas_10_votos.tconfint_mean()
# Out:
# (3.4226560546570113, 3.4649650888361565)

# %% [markdown]
# Al usar 'tconfint_mean' nos devuelve los intervalos de confianza, cuyos valores son parecidos al anterior método

# %%
#Calculando  Z Test y  T Test usando 'DescrStatsW'
from statsmodels.stats.weightstats import DescrStatsW # PAra calcular el intervalo de confianza con el Test T usamos 'DescrStatsW'

descr_notas_10_votos= DescrStatsW(nota_promedio_por_pelicula_10_o_mas_votos)
descr_notas_10_votos.tconfint_mean()
# Out:
# (3.4226560546570113, 3.4649650888361565)

# %%
#Calculando  Z Test y  T Test usando 'DescrStatsW'
descr_notas_10_votos.zconfint_mean()
# Out:
# (3.422668132218516, 3.464953011274652)

# %% [markdown]
# Gabriel es un Analista de Datos Jr. en una empresa de Data Science. Cierto día le pidieron que analice por qué los datos siempre retornaban valores aleatorios y que corrija el problema. ¿Cómo Gabriel puede hacer con que los datos no retornen más de manera aleatoria?
#
# Respuesta: Definir una semilla (SEED) hace que los números aleatorios sean generados siempre de la misma forma, tornando nuestra operación replicable.
#
#
# Aprendimos:
# - Lo que es una SEED;
# - Como simplificar nuestro código;
# - Como generar una orden aleatoria;
# - Descubrir intervalo de confianza con tconfint();
# - Describir nuestros datos en forma estadística;

# %% [markdown]
# #4. OTROS TEST ESTADÍSTICOS
#
# ## 4.1 Test para una muestra

# %%
#media = 3.43
#int(3.41, 3.45)

# %%
peliculas = pd.read_csv('movies.csv')

# %%
peliculas.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#Analizando una PElicula Espesífica
notas1= notas.query('movieId == 1') #Analizamos Toy Story (1995)
notas1
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 516         5        1     4.0   847434962
# 874         7        1     4.5  1106635946
# 1434       15        1     2.5  1510577970
# 1667       17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [215 rows x 4 columns]

# %% [markdown]
# La tabla muesta todas las notas en que los usuarios dieron su respectiva valoración de la película Toy Story (1995)

# %%
#Gráfico de Distribución
ax= sns.distplot(notas1.rating)
ax.set(xlabel='Nota Toy Story', ylabel = 'Densidad')
ax.set_title('Gráfico de Distribución de Notas Toy Story')
# Out:
# <ipython-input-53-395c55d61574>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(notas1.rating)
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Toy Story')

# %%
#Gráficamos el BoxPlot
ax= sns.boxplot(x= notas1.rating)
ax.set(xlabel='Nota Toy Story')
ax.set_title('Gráfico de Distribución de Notas Toy Story')
# Out:
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Toy Story')

# %% [markdown]
# Como la mediana de Toy Story es 4 > 3.5 que la del promedio de peliculas, se puede afirmar que las notas de Toy Story son mejores que las del promedio de todas las películas.

# %%
#Calculamos el intervalo de confianza de Toy Story
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
#Calculamos el ztest Para comparar las notas de Toy Story con las del promedio general de películas
from statsmodels.stats.weightstats import ztest
ztest(notas1.rating, nota_promedio_por_pelicula_10_o_mas_votos)
# Out:
# (12.420023799815938, 2.03500947979381e-35)

# %% [markdown]
# Lo que nos retorna esta información esel 'tstat' (12.420023799815938) y el 'pvalue' (2.03500947979381e-35)
#
# Como 2.03 e35 < 0.05 Se rechaza la Hipotesis Nula, el valor promedio de notas de Toy Story es igual al valor promedio de Notas de todas las Películas. Por tanto, se concidera que la media de Toy Story es mayor que le media de las películas en general.

# %% [markdown]
# ## 4.2 Problemas con muestras pequeñas

# %%
#Validamos si el comportamiento es el mismo otorgando un orden aleatorio para Toy Story

np.random.seed(75243)#Colocamos una semilla, un parametro fijo de 75243
temp =notas1.sample(frac=1).rating

promedios = list()
for i in range(1, len(temp)):
  promedios.append(temp[0:i].mean())

promedios

plt.plot(promedios)

# %%
#Validamos si el comportamiento es el mismo otorgando un orden aleatorio para Toy Story

np.random.seed(75243)#Colocamos una semilla, un parametro fijo de 75243
temp =notas1.sample(frac=1).rating

promedios = list()

def calcula_test(i):
  media= temp[0:i].mean()
  stat, p = ztest(temp[0:i], value= 3.443810571746584 )
  return(i,p, media)

for i in range(1, len(temp)):
  promedios.append(calcula_test(i))

promedios# Retorna una lista con dos valores (Pvalue y media)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/weightstats.py:1559: RuntimeWarning: invalid value encountered in scalar divide
#   var = x1_var / (nobs1 - ddof)
# [(1, nan, 4.5),
#  (2, 0.001260793217334606, 4.25),
#  (3, 0.05401743978189464, 4.0),
#  (4, 0.006434812652838548, 4.0),
#  (5, 0.00301681888599817, 4.2),
#  (6, 0.054017439781894674, 4.0),
#  (7, 0.0226255896842269, 4.0),
#  (8, 0.005524289289449109, 4.125),
#  (9, 0.002099337939991173, 4.111111111111111),
#  (10, 0.0007353007606570625, 4.1),
#  (11, 0.005961816063376637, 4.0),
#  (12, 0.002592453173443772, 4.0),
#  (13, 0.0006384125384598691, 4.038461538461538),
#  (14, 0.0002418155790513635, 4.035714285714286),
#  (15, 8.61226573970421e-05, 4.033333333333333),
#  (16, 2.883034686789589e-05, 4.03125),
#  (17, 0.00028593328119689914, 3.9705882352941178),
#  (18, 8.288393372323729e-05, 4.027777777777778),
#  (19, 2.120564260960821e-05, 4.078947368421052),
#  (20, 4.6478258536588505e-06, 4.1),
# ...

# %%
#Convertidmos en un  Array la variable promedio
valores = np.array(promedios)

# %%
plt.plot(valores[:,0], valores[:,1])#Columna 1
plt.plot(valores[:,0], valores[:,2])#Columna 2
plt.hlines(y=0.05, xmin=2, xmax= len(temp), colors = 'g', linestyles= 'dashdot') #Agregamos una línea de tendencia 'dashdot'

# %% [markdown]
# El Gráfico naranja representa el promedio y el gráfico azul el pvalue, la mayor oscilación se encuentra concentrada en los primerios 50 registros.
#
# Aprendimos:
# - Lo que es, como utilizar y cuando utilizar el Test-Z y el Test-T;

# %% [markdown]
# #5.TEST PARA DOS MUESTRAS
#
# ## 5.1 Comparando la media de dos muestras

# %%
#Generamos el intervalo de confianza de Toy Story y las Notas en General
zconfint( notas1.rating, notas.rating)
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %%
ztest(notas.rating, notas1.rating)
# Out:
# (-5.894327101501841, 3.762112778881965e-09)

# %%
# Realizar una prueba t de Student para dos muestras independientes. Esta prueba se utiliza para determinar si hay una diferencia significativa entre las medias de dos grupos independientes.
from scipy.stats import ttest_ind
ttest_ind(notas1.rating, notas.rating)
# Out:
# TtestResult(statistic=5.894327101501841, pvalue=3.774003138720876e-09, df=101049.0)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todas_las_notas= DescrStatsW(notas.rating)
descr_toy_story= DescrStatsW(notas1.rating)

comparacion= descr_todas_las_notas.get_compare(descr_toy_story)#Comparamos descr_todas_las_notas con descr_toy_story

comparacion.summary()#Si no se coloca ningun parámetro con Summary, se nos devuelve el Z Test por defecto
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todas_las_notas= DescrStatsW(notas.rating)
descr_toy_story= DescrStatsW(notas1.rating)

comparacion= descr_todas_las_notas.get_compare(descr_toy_story)#Comparamos descr_todas_las_notas con descr_toy_story

comparacion.summary(use_t=True)#compara valores
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 5.2 Visualizando graficamente - muestras pequenas

# %%
import matplotlib.pyplot as plt
plt.boxplot([notas.rating, notas1.rating], labels=['Notas General', 'Notas Toy Story'])
plt.title('Distribución de todas las Notas, y Toy Story')
# Out:
# Text(0.5, 1.0, 'Distribución de todas las Notas, y Toy Story')

# %%
import matplotlib.pyplot as plt
plt.boxplot([notas.rating, notas1[3:12].rating], labels=['Notas General', 'Notas Toy Story 3  al 12'])
plt.title('Distribución de todas las Notas, y Toy Story del 3 al 12')
# Out:
# Text(0.5, 1.0, 'Distribución de todas las Notas, y Toy Story del 3 al 12')

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todas_las_notas= DescrStatsW(notas.rating)
descr_toy_story_3_12= DescrStatsW(notas1[3:12].rating)

comparacion= descr_todas_las_notas.get_compare(descr_toy_story_3_12)#Comparamos descr_todas_las_notas con descr_toy_story

comparacion.summary(use_t=True)#compara valores
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Descartamos Ho de que los valores son iguales ya que el pvalue es > 5%. Además, al tener en cuenta el Intervalo de confianza se observa que hay datos insuficientes para tomar una conclusión asertiva. La cantidad de datos en la muestra es relevante.
#
# Aprendimos:
#
# - Generar un intervalo de confianza de las medias de nuestras distribuciones;
# - Utilizar get_compare() de statsmodels;
# - Comparar medias;
# - Utilizar summary();

# %% [markdown]
# # 6 TEST NO PARAMÉTRICOS
#
# ## 6.1 Comparando películas

# %%
peliculas.query('movieId in (1,593,72226) ')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas1= notas.query('movieId == 1 ')
notas593= notas.query('movieId == 593 ')
notas72226= notas.query('movieId == 72226 ')

# %%
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
import matplotlib.pyplot as plt

plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels=['Toy Story', 'Silence of the Lambs', 'Fantastic Mr. Fox '])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eab5a38f8e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eab5a7211b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eab5a38c7f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7eab5b85e3b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7eab5b218b20>,
# ...
#  'means': []}

# %%
import seaborn as sns
sns.boxplot(x= 'movieId', y= 'rating', data= notas.query('movieId in (1,593,72226)'))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
#Calucluamos en número de muestras de cada variable
notas.query('movieId in (1,593,72226)').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
#Comparamos las películas para ver cual de ellas es mejor
# 1 Vs 593
from statsmodels.stats.weightstats import DescrStatsW

descr_1= DescrStatsW(notas1.rating)
descr_593= DescrStatsW(notas593.rating)

comparacion= descr_1.get_compare(descr_593)
comparacion.summary()#Las muestra son grandes por lo que no usamos el parámetro use_t=True, es decir el Tets Z (215 y 279 muestras)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Los datos permiten concluir que Silence of the Lambs esta mejor evaluada que Toy Story, dado que pvalue es > 5% por lo que se descarta Ho. de que las notas de ambas películas son iguales. Además, se puede afirmar que Toy Story tiene notas menores dadas en le rango -0.391	-0.090

# %%
#Comparamos las películas para ver cual de ellas es mejor
# 1 Vs 72226
from statsmodels.stats.weightstats import DescrStatsW

descr_1= DescrStatsW(notas1.rating)
descr_72226= DescrStatsW(notas72226.rating)

comparacion= descr_1.get_compare(descr_72226)
comparacion.summary(use_t=True)# Usamos el Test T ya que esta variable tiene solo 18 muestras
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# - Rechazamos Ho porque Pvalue > 0.05
# - Se observa un intervalo inconsistente porque tengo un dato negativo y uno positivo. Por lo que se puede concluir que los datos no son suficientes para definir que pelicula es mejor que la otra.

# %%
#Comparamos las películas para ver cual de ellas es mejor
# 593 Vs 72226
from statsmodels.stats.weightstats import DescrStatsW

descr_593= DescrStatsW(notas593.rating)
descr_72226= DescrStatsW(notas72226.rating)

comparacion= descr_593.get_compare(descr_72226)
comparacion.summary(use_t=True)# Usamos el Test T ya que esta variable tiene solo 18 muestras
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# - Rechazamos Ho porque Pvalue > 0.05
# - Se observa un intervalo inconsistente porque tengo un dato negativo y uno positivo. Por lo que se puede concluir que los datos no son suficientes para definir que pelicula es mejor que la otra.

# %% [markdown]
# ## 6.2 Comparación no paramétrica con Wilcoxon Ranksum

# %%
ax= sns.distplot(tmdb_10_o_mas_votos.vote_average)
ax.set(xlabel='Nota Promedio', ylabel = 'Frecuencia')
ax.set_title('Gráfico de Distribución de Notas Promedio TMDB')
# Out:
# <ipython-input-84-b2be0155e1af>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb_10_o_mas_votos.vote_average)
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio TMDB')

# %%
ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values)
ax.set(xlabel='Nota Promedio', ylabel = '% Acumulado')
ax.set_title('Gráfico de Distribución de Notas Promedio MoviLens')
# Out:
# <ipython-input-85-5b0593add4ac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(nota_promedio_por_pelicula_10_o_mas_votos.values)
# Text(0.5, 1.0, 'Gráfico de Distribución de Notas Promedio MoviLens')

# %%
from scipy.stats import normaltest

# %%
stat, p = normaltest(notas1.rating)
p
# Out:
# 0.00011053430732728716

# %% [markdown]
# - Ho: La distribución es Normal
# - En este caso p < 0.05 por tanto se rechaza Ho

# %%
from scipy.stats import ranksums
stat, p = ranksums(notas1.rating, notas593.rating)
p
# Out:
# 0.0003267718756440693

# %% [markdown]
# - Ho: Las dos muestras tienen la misma distribución
# - H1: Los valores de una muestra tienden a ser mayores que la otra
# - En este caso p < 0.05 por tanto se rechaza Ho
#
#
# Aprendimos:
#
# - Utilizar seaborn para mostrar gráfico;
# - Agrupar los valores;
# - Comparar medias diferentes;
# - Utilizar normaltest;
# - Test no paramétrico;
# - Utilizar ranksums
